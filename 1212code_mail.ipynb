# %%
import pandas as pd
import numpy as np
day=86400000
reader = pd.read_csv(r'C:\shenwo\8.1.csv',low_memory=False)            #把数据读入reader
s0= reader[reader.mile >0]                                          #筛选出tmail 数据给S
s=s0.sort_values('TIMESTAMP',ascending=True)[["TIMESTAMP", "mile"]]# S0中选取 时间戳和tmail 并升序排序
s1=s[s.TIMESTAMP<1472486400000]   #选择8月29日
print s1.head()
import matplotlib.pyplot as plt  # 画图
plt.figure(1)
plt.scatter((s1.TIMESTAMP-1472400000000)/3600000.0,s1.mile-s1.iloc[0,1])
plt.show()
# Out:
#             TIMESTAMP       mile
# 552909  1472422184819  11326.438
# 552894  1472422213877  11326.438
# 552879  1472422243872  11326.438
# 552865  1472422273892  11326.438
# 552852  1472422303891  11326.438
