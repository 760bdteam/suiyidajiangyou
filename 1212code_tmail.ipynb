# %%
import pandas as pd
import numpy as np
day=86400000
reader = pd.read_csv(r'C:\shenwo\8.1.csv',low_memory=False)            #把数据读入reader
s0= reader[reader.tmile >0]                                          #筛选出tmail 数据给S
s=s0.sort_values('TIMESTAMP',ascending=True)[["TIMESTAMP", "tmile"]]# S0中选取 时间戳和tmail 并升序排序
s1=s[s.TIMESTAMP<1472486400000]   #选择8月29日
print s1.head()
import matplotlib.pyplot as plt  # 画图
plt.figure(1)
plt.scatter((s1.TIMESTAMP-1472400000000)/3600000.0,s1.tmile-s1.iloc[0,1])
plt.show()
# Out:
#             TIMESTAMP    tmile
# 552907  1472422186908  12667.2
# 552905  1472422191952  12667.2
# 552903  1472422196960  12667.2
# 552900  1472422201910  12667.2
# 552898  1472422206908  12667.2
