# %%
#coding=utf-8
import pandas as pd
import numpy as np
day=86400000
day_on=1472400000000
reader = pd.read_csv(r'C:\shenwo\8.1.csv',low_memory=False)            #把数据读入reader
s0= reader[reader.tmile >0][["TIMESTAMP", "tmile"]]                  #筛选出tmail，TIMESTAMP 数据给S
s=s0.sort_values('TIMESTAMP',ascending=True)# 升序排序
s1=s[s.TIMESTAMP<1472486400000]   #选择8月29日
s2=s[s.TIMESTAMP<1472572800000][s.TIMESTAMP>1472486400000]
s3=s[s.TIMESTAMP<1472659200000][s.TIMESTAMP>1472572800000]
print s2.head()
import matplotlib.pyplot as plt  # 画图
plt.figure(1)
plt.scatter((s1.TIMESTAMP-1472400000000)/3600000.0,s1.tmile-s1.iloc[0,1])
plt.figure(2)
plt.scatter((s2.TIMESTAMP-1472486400000)/3600000.0,s2.tmile-s2.iloc[0,1])
plt.figure(3)
plt.scatter((s3.TIMESTAMP-1472572800000)/3600000.0,s3.tmile-s3.iloc[0,1])
plt.show()
# Out:
# c:\python27\lib\site-packages\ipykernel\__main__.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# c:\python27\lib\site-packages\ipykernel\__main__.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#             TIMESTAMP    tmile
# 529418  1472508249860  12740.5
# 529415  1472508255057  12740.5
# 529413  1472508259870  12740.5
# 529411  1472508264854  12740.5
# 529408  1472508270011  12740.5
